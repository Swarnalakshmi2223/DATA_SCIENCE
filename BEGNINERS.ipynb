# %% [markdown]
# <a href="https://colab.research.google.com/github/Swarnalakshmi2223/DATA_SCIENCE/blob/main/BEGNINERS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/COVID.csv')

# %%
data.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
data.corr()
# Out:
# <ipython-input-10-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                         Confirmed    Deaths  Recovered    Active  New cases  \
# Confirmed                1.000000  0.934698   0.906377  0.927018   0.909720
# Deaths                   0.934698  1.000000   0.832098  0.871586   0.806975
# Recovered                0.906377  0.832098   1.000000  0.682103   0.818942
# Active                   0.927018  0.871586   0.682103  1.000000   0.851190
# New cases                0.909720  0.806975   0.818942  0.851190   1.000000
# New deaths               0.871683  0.814161   0.820338  0.781123   0.935947
# New recovered            0.859252  0.765114   0.919203  0.673887   0.914765
# Deaths / 100 Cases       0.063550  0.251565   0.048438  0.054380   0.020104
# ...

# %% [markdown]
# #correlation map

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()
# Out:
# <ipython-input-11-36a057762ca3>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
data.head(40)
# Out:
#               Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0                Afghanistan      36263    1269      25198    9796        106
# 1                    Albania       4880     144       2745    1991        117
# 2                    Algeria      27973    1163      18837    7973        616
# 3                    Andorra        907      52        803      52         10
# 4                     Angola        950      41        242     667         18
# 5        Antigua and Barbuda         86       3         65      18          4
# 6                  Argentina     167416    3059      72575   91782       4890
# 7                    Armenia      37390     711      26665   10014         73
# 8                  Australia      15303     167       9311    5825        368
# 9                    Austria      20558     713      18246    1599         86
# 10                Azerbaijan      30446     423      23242    6781        396
# ...

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %% [markdown]
# MATPLOTLIB

# %% [markdown]
# Line Plot

# %%
# Line Plot
# color = color, label = label, linewidth = width of line, alpha = opacity, grid = grid, linestyle = sytle of line
data.Recovered.plot(kind = 'line', color = 'blue',label = 'Recovered',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data.Active.plot(color = 'r',label = 'Active',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('Line Plot')            # title = title of plot
plt.show()

# %% [markdown]
# Scatter Plot

# %%
# x = Confirmed last week	, y = 1 week change
data.plot(kind='scatter',x='Confirmed last week', y='1 week change',alpha = 0.5,color = 'red')
plt.xlabel('Confirmed last week')              # label = name of label
plt.ylabel('1 week change	')
plt.title('Confirmed last week and 1 week change')
# Out:
# Text(0.5, 1.0, 'Confirmed last week and 1 week change')
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Histogram

# %%
data.Recovered.plot(kind = 'hist',bins = 50,figsize = (12,12))
plt.show()

# %% [markdown]
# DICTIONARY

# %%
dictionary = {'india' : 'delhi','usa' : 'vegas'}
print(dictionary.keys())
print(dictionary.values())
# Out:
# dict_keys(['india', 'usa'])
# dict_values(['delhi', 'vegas'])

# %% [markdown]
# PANDAS:
# CSV: comma - separated values

# %%
data = pd.read_csv('/content/drive/MyDrive/COVID.csv')

# %%
series = data['Recovered']        # data['Defense'] = series
print(type(series))
data_frame = data[['Recovered']]  # data[['Defense']] = data frame
print(type(data_frame))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Filtering Pandas data frame

# %%
x = data['Recovered']>200     # There are only 3 pokemons who have higher defense value than 200
data[x]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 181             Vietnam        431       0        365      66         11
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# Filtering pandas with logical

# %%
data[np.logical_and(data['Recovered']>200, data['Active']>100 )]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 4                Angola        950      41        242     667         18
# 6             Argentina     167416    3059      72575   91782       4890
# ..                  ...        ...     ...        ...     ...        ...
# 180           Venezuela      15988     146       9959    5883        525
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# WHILE and FOR LOOPS

# %%
i = 0
while i != 10 :
    print('i is: ',i)
    i +=1
print(i,' is equal to 10')
# Out:
# i is:  0
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# i is:  5
# i is:  6
# i is:  7
# i is:  8
# i is:  9
# 10  is equal to 10

# %%
# Stay in loop if condition( i is not equal 5) is true
lis = [1,2,3,4,5]
for i in lis:
    print('i is: ',i)
print('')

# Enumerate index and value of list
# index : value = 0:1, 1:2, 2:3, 3:4, 4:5
for index, value in enumerate(lis):
    print(index," : ",value)
print('')

# For dictionaries
# We can use for loop to achive key and value of dictionary. We learnt key and value at dictionary part.
dictionary = {'india':'delhi','usa':'vegas'}
for key,value in dictionary.items():
    print(key," : ",value)
print('')

# For pandas we can achieve index and value
for index,value in data[['Active']][0:1].iterrows():
    print(index," : ",value)
# Out:
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# i is:  5
#
# 0  :  1
# 1  :  2
# 2  :  3
# 3  :  4
# 4  :  5
#
# india  :  delhi
# usa  :  vegas
#
# 0  :  Active    9796
# Name: 0, dtype: int64

# %% [markdown]
# PYTHON DATA SCIENCE TOOLBOX

# %%
def tuple_ex():
    """ return defined t tuple"""
    t = (1,2,3)
    return t
a,b,c = tuple_ex()
print(a,b,c)
# Out:
# 1 2 3

# %% [markdown]
# SCOPE:built in scope

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
# ...

# %% [markdown]
# DEFAULT and FLEXIBLE ARGUMENTS

# %% [markdown]
# # default arguments:

# %%
def f(a, b = 1, c = 2):
    y = a + b + c
    return y
print(f(5))
print(f(5,4,3))
# Out:
# 8
# 12

# %% [markdown]
#  flexible arguments *args

# %%
def f(*args):
    for i in args:
        print(i)
f(1)
print("")
f(1,2,3,4)
# Out:
# 1
#
# 1
# 2
# 3
# 4

# %% [markdown]
# flexible arguments **kwargs that is dictionary

# %%
def f(**kwargs):
    """ print key and value of dictionary"""
    for key, value in kwargs.items():               # If you do not understand this part turn for loop part and look at dictionary in for loop
        print(key, " ", value)
f(country = 'spain', capital = 'madrid', population = 123456)
# Out:
# country   spain
# capital   madrid
# population   123456

# %% [markdown]
# LAMBDA FUNCTION

# %%
square = lambda x: x**4
print(square(4))
tot = lambda x,y,z: x+y+z
print(tot(1,2,3))
# Out:
# 256
# 6

# %% [markdown]
# ANONYMOUS FUNCTİON

# %%
number_list = [1,2,3]
y = map(lambda x:x**4,number_list)
print(list(y))
# Out:
# [1, 16, 81]

# %% [markdown]
# LIST COMPREHENSİON

# %%
num1 = [1,4,3]
num2 = [i + 1 for i in num1 ]
print(num2)
# Out:
# [2, 5, 4]

# %%
num1 = [3,9,12]
num2 = [i**2 if i == 10 else i-5 if i < 7 else i+5 for i in num1]
print(num2)
# Out:
# [-2, 14, 17]

# %% [markdown]
# CLEANING DATA

# %%
data.tail()
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
data.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
data.shape
# Out:
# (187, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
print(data['New deaths'].value_counts(dropna =False))
# Out:
# 0       91
# 1       17
# 2       11
# 3        7
# 6        7
# 4        7
# 5        6
# 17       3
# 11       3
# 20       2
# 7        2
# 9        2
# 13       2
# 8        2
# 27       2
# 342      1
# 24       1
# 10       1
# 96       1
# 28       1
# 575      1
# 19       1
# 85       1
# 298      1
# 16       1
# 46       1
# 212      1
# 57       1
# 637      1
# 50       1
# 508      1
# 75       1
# 614      1
# 14       1
# 64       1
# 37       1
# 120      1
# 1076     1
# Name: New deaths, dtype: int64

# %%
data.describe() #ignore null entries
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %% [markdown]
# VISUAL EXPLORATORY DATA ANALYSIS

# %%
data.boxplot(column='New deaths',by = 'Active')
# Out:
# <Axes: title={'center': 'New deaths'}, xlabel='Active'>

# %% [markdown]
# TIDY DATA

# %%
data_new = data.head()    # I only take 5 rows into new data
data_new
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %% [markdown]
# CONCATENATING DATA

# %%
data1 = data.head()
data2= data.tail()
conc_data_row = pd.concat([data1,data2],axis =0,ignore_index =True) # axis = 0 : adds dataframes in row
conc_data_row
# Out:
#        Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0         Afghanistan      36263    1269      25198    9796        106
# 1             Albania       4880     144       2745    1991        117
# 2             Algeria      27973    1163      18837    7973        616
# 3             Andorra        907      52        803      52         10
# 4              Angola        950      41        242     667         18
# 5  West Bank and Gaza      10621      78       3752    6791        152
# 6      Western Sahara         10       1          8       1          0
# 7               Yemen       1691     483        833     375         10
# 8              Zambia       4552     140       2815    1597         71
# 9            Zimbabwe       2704      36        542    2126        192
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# ...

# %%
data1 = data['New cases'].head()
data2= data['New deaths'].head()
conc_data_col = pd.concat([data1,data2],axis =1) # axis = 1 : adds dataframes in column
conc_data_col
# Out:
#    New cases  New deaths
# 0        106          10
# 1        117           6
# 2        616           8
# 3         10           0
# 4         18           1

# %% [markdown]
# DATA TYPES

# %%
data.dtypes
# Out:
# Country/Region             object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# Confirmed last week         int64
# 1 week change               int64
# 1 week % increase         float64
# WHO Region                 object
# dtype: object

# %% [markdown]
# MISSING DATA and TESTING WITH ASSERT

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
data["Recovered"].value_counts(dropna =False)
# Out:
# 0         6
# 18        2
# 803       2
# 128       2
# 39        2
#          ..
# 922       1
# 190314    1
# 29801     1
# 1374      1
# 542       1
# Name: Recovered, Length: 178, dtype: int64

# %% [markdown]
#  PANDAS FOUNDATION

# %%
country = ["india","canada"]
population = ["100","50"]
list_label = ["country","population"]
list_col = [country,population]
zipped = list(zip(list_label,list_col))
data_dict = dict(zipped)
df = pd.DataFrame(data_dict)
df
# Out:
#   country population
# 0   india        100
# 1  canada         50

# %%
df["capital"] = ["delhi","ottawa"]
df
# Out:
#   country population capital
# 0   india        100   delhi
# 1  canada         50  ottawa

# %%
df["income"] = 1
df
# Out:
#   country population capital  income
# 0   india        100   delhi       1
# 1  canada         50  ottawa       1

# %% [markdown]
# VISUAL EXPLORATORY DATA ANALYSIS

# %%
data1 = data.loc[:,["Active","New cases","New deaths"]]
data1.plot()
# Out:
# <Axes: >

# %%
data1.plot(subplots = True)
plt.show()

# %%
data1.plot(kind = "scatter",x="Active",y = "New cases")
plt.show()

# %% [markdown]
# STATISTICAL EXPLORATORY DATA ANALYSIS

# %%
data.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %% [markdown]
# INDEXING PANDAS TIME SERIES

# %%
time_list = ["1992-03-08","1992-04-12"]
print(type(time_list[1])) # As you can see date is string
# however we want it to be datetime object
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
import warnings
warnings.filterwarnings("ignore")
# In order to practice lets take head of pokemon data and add it a time list
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object
# lets make date as index
data2= data2.set_index("date")
data2
# Out:
#            Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# date
# 1992-01-10    Afghanistan      36263    1269      25198    9796        106
# 1992-02-10        Albania       4880     144       2745    1991        117
# 1992-03-10        Algeria      27973    1163      18837    7973        616
# 1993-03-15        Andorra        907      52        803      52         10
# 1993-03-16         Angola        950      41        242     667         18
#
#             New deaths  New recovered  Deaths / 100 Cases  \
# date
# 1992-01-10          10             18                3.50
# 1992-02-10           6             63                2.95
# 1992-03-10           8            749                4.16
# 1993-03-15           0              0                5.73
# 1993-03-16           1              0                4.32
#
#             Recovered / 100 Cases  Deaths / 100 Recovered  \
# date
# 1992-01-10                  69.49                    5.04
# ...

# %%
print(data2.loc["1993-03-16"])
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
# Country/Region            Angola
# Confirmed                    950
# Deaths                        41
# Recovered                    242
# Active                       667
# New cases                     18
# New deaths                     1
# New recovered                  0
# Deaths / 100 Cases          4.32
# Recovered / 100 Cases      25.47
# Deaths / 100 Recovered     16.94
# Confirmed last week          749
# 1 week change                201
# 1 week % increase          26.84
# WHO Region                Africa
# Name: 1993-03-16 00:00:00, dtype: object
#            Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# date
# 1992-03-10        Algeria      27973    1163      18837    7973        616
# 1993-03-15        Andorra        907      52        803      52         10
# 1993-03-16         Angola        950      41        242     667         18
#
#             New deaths  New recovered  Deaths / 100 Cases  \
# date
# ...

# %% [markdown]
# RESAMPLING PANDAS TIME SERIES

# %%
data2.resample("A").mean()
# Out:
#                Confirmed      Deaths     Recovered       Active   New cases  \
# date
# 1992-12-31  23038.666667  858.666667  15593.333333  6586.666667  279.666667
# 1993-12-31    928.500000   46.500000    522.500000   359.500000   14.000000
#
#             New deaths  New recovered  Deaths / 100 Cases  \
# date
# 1992-12-31         8.0     276.666667            3.536667
# 1993-12-31         0.5       0.000000            5.025000
#
#             Recovered / 100 Cases  Deaths / 100 Recovered  \
# date
# 1992-12-31                  64.36                5.486667
# 1993-12-31                  57.00               11.710000
#
#             Confirmed last week  1 week change  1 week % increase
# date
# 1992-12-31         21129.333333    1909.333333              12.38
# 1993-12-31           816.500000     112.000000              14.72

# %%
data2.resample("M").mean()
# Out:
#             Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# date
# 1992-01-31    36263.0  1269.0    25198.0  9796.0      106.0        10.0
# 1992-02-29     4880.0   144.0     2745.0  1991.0      117.0         6.0
# 1992-03-31    27973.0  1163.0    18837.0  7973.0      616.0         8.0
# 1992-04-30        NaN     NaN        NaN     NaN        NaN         NaN
# 1992-05-31        NaN     NaN        NaN     NaN        NaN         NaN
# 1992-06-30        NaN     NaN        NaN     NaN        NaN         NaN
# 1992-07-31        NaN     NaN        NaN     NaN        NaN         NaN
# 1992-08-31        NaN     NaN        NaN     NaN        NaN         NaN
# 1992-09-30        NaN     NaN        NaN     NaN        NaN         NaN
# 1992-10-31        NaN     NaN        NaN     NaN        NaN         NaN
# 1992-11-30        NaN     NaN        NaN     NaN        NaN         NaN
# 1992-12-31        NaN     NaN        NaN     NaN        NaN         NaN
# ...

# %%
data2.resample("M").first().interpolate("linear")
# Out:
#            Country/Region  Confirmed       Deaths     Recovered       Active  \
# date
# 1992-01-31    Afghanistan    36263.0  1269.000000  25198.000000  9796.000000
# 1992-02-29        Albania     4880.0   144.000000   2745.000000  1991.000000
# 1992-03-31        Algeria    27973.0  1163.000000  18837.000000  7973.000000
# 1992-04-30           None    25717.5  1070.416667  17334.166667  7312.916667
# 1992-05-31           None    23462.0   977.833333  15831.333333  6652.833333
# 1992-06-30           None    21206.5   885.250000  14328.500000  5992.750000
# 1992-07-31           None    18951.0   792.666667  12825.666667  5332.666667
# 1992-08-31           None    16695.5   700.083333  11322.833333  4672.583333
# 1992-09-30           None    14440.0   607.500000   9820.000000  4012.500000
# 1992-10-31           None    12184.5   514.916667   8317.166667  3352.416667
# 1992-11-30           None     9929.0   422.333333   6814.333333  2692.333333
# ...

# %%
data2.resample("M").mean().interpolate("linear")
# Out:
#                Confirmed       Deaths     Recovered       Active   New cases  \
# date
# 1992-01-31  36263.000000  1269.000000  25198.000000  9796.000000  106.000000
# 1992-02-29   4880.000000   144.000000   2745.000000  1991.000000  117.000000
# 1992-03-31  27973.000000  1163.000000  18837.000000  7973.000000  616.000000
# 1992-04-30  25719.291667  1069.958333  17310.791667  7338.541667  565.833333
# 1992-05-31  23465.583333   976.916667  15784.583333  6704.083333  515.666667
# 1992-06-30  21211.875000   883.875000  14258.375000  6069.625000  465.500000
# 1992-07-31  18958.166667   790.833333  12732.166667  5435.166667  415.333333
# 1992-08-31  16704.458333   697.791667  11205.958333  4800.708333  365.166667
# 1992-09-30  14450.750000   604.750000   9679.750000  4166.250000  315.000000
# 1992-10-31  12197.041667   511.708333   8153.541667  3531.791667  264.833333
# 1992-11-30   9943.333333   418.666667   6627.333333  2897.333333  214.666667
# ...

# %% [markdown]
# MANIPULATING DATA FRAMES WITH PANDAS

# %%
data= data.set_index("Active")
data.head()
# Out:
#        Country/Region  Confirmed  Deaths  Recovered  New cases  New deaths  \
# Active
# 9796      Afghanistan      36263    1269      25198        106          10
# 1991          Albania       4880     144       2745        117           6
# 7973          Algeria      27973    1163      18837        616           8
# 52            Andorra        907      52        803         10           0
# 667            Angola        950      41        242         18           1
#
#         New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Active
# 9796               18                3.50                  69.49
# 1991               63                2.95                  56.25
# 7973              749                4.16                  67.34
# 52                  0                5.73                  88.53
# 667                 0                4.32                  25.47
#
#         Deaths / 100 Recovered  Confirmed last week  1 week change  \
# Active
# ...

# %%
data["Recovered"][1]
# Out:
# Active
# 1    13
# 1    19
# 1     8
# Name: Recovered, dtype: int64

# %%
data.loc[1,["Deaths"]]
# Out:
#         Deaths
# Active
# 1            0
# 1            0
# 1            1

# %%
data[["New cases","New deaths"]]
# Out:
#         New cases  New deaths
# Active
# 9796          106          10
# 1991          117           6
# 7973          616           8
# 52             10           0
# 667            18           1
# ...           ...         ...
# 6791          152           2
# 1               0           0
# 375            10           4
# 1597           71           1
# 2126          192           2
#
# [187 rows x 2 columns]

# %% [markdown]
# SLICING DATA FRAME

# %%
print(type(data["Deaths"]))     # series
print(type(data[["Deaths"]]))   # data frames
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
data.loc[ : ,"Deaths":"New deaths"]
# Out:
#         Deaths  Recovered  New cases  New deaths
# Active
# 9796      1269      25198        106          10
# 1991       144       2745        117           6
# 7973      1163      18837        616           8
# 52          52        803         10           0
# 667         41        242         18           1
# ...        ...        ...        ...         ...
# 6791        78       3752        152           2
# 1            1          8          0           0
# 375        483        833         10           4
# 1597       140       2815         71           1
# 2126        36        542        192           2
#
# [187 rows x 4 columns]

# %%
data.loc[ : ,"Recovered":]
# Out:
#         Recovered  New cases  New deaths  New recovered  Deaths / 100 Cases  \
# Active
# 9796        25198        106          10             18                3.50
# 1991         2745        117           6             63                2.95
# 7973        18837        616           8            749                4.16
# 52            803         10           0              0                5.73
# 667           242         18           1              0                4.32
# ...           ...        ...         ...            ...                 ...
# 6791         3752        152           2              0                0.73
# 1               8          0           0              0               10.00
# 375           833         10           4             36               28.56
# 1597         2815         71           1            465                3.08
# 2126          542        192           2             24                1.33
#
# ...

# %% [markdown]
# FILTERING DATA FRAMES

# %%
boolean = data.Active > 200
data[boolean]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 4                Angola        950      41        242     667         18
# 6             Argentina     167416    3059      72575   91782       4890
# ..                  ...        ...     ...        ...     ...        ...
# 180           Venezuela      15988     146       9959    5883        525
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# CATEGORICALS AND GROUPBY

# %%
df
# Out:
#   country population capital  income
# 0   india        100   delhi       1
# 1  canada         50  ottawa       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     2 non-null      object
#  1   population  2 non-null      object
#  2   capital     2 non-null      object
#  3   income      2 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 192.0+ bytes
